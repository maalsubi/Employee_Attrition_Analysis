# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set up the plotting environment
sns.set(style="whitegrid")

# %%
# Load the dataset
file_path = 'D:\\INTERNSHIP\\Attrition data.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department
# 0           1   51        No      Travel_Rarely                   Sales  \
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...
# 0                 6          2  Life Sciences              1  Female  ...  \
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
data.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0  \
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike
# count  4410.000000    4410.000000         4391.000000        4410.000000  \
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
#Getting the unique categorical values
for i in data.columns:
    if(data[i].dtypes=='object'):
        print("Unique Values of ",i)
        print(data[i].unique())
# Out:
# Unique Values of  Attrition
# ['No' 'Yes']
# Unique Values of  BusinessTravel
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Unique Values of  Department
# ['Sales' 'Research & Development' 'Human Resources']
# Unique Values of  EducationField
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Unique Values of  Gender
# ['Female' 'Male']
# Unique Values of  JobRole
# ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# Unique Values of  MaritalStatus
# ['Married' 'Single' 'Divorced']
# Unique Values of  Over18
# ['Y']

# %%
data.isna().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %% [markdown]
# DATA PREPROCESSING

# %%
data['NumCompaniesWorked'].fillna(data['NumCompaniesWorked'].mean(),inplace=True)
data['EnvironmentSatisfaction'].fillna(data['EnvironmentSatisfaction'].mean(),inplace=True)
data['JobSatisfaction'].fillna(data['JobSatisfaction'].mean(),inplace=True)
data['WorkLifeBalance'].fillna(data['WorkLifeBalance'].mean(),inplace=True)
data['TotalWorkingYears'].fillna(data['TotalWorkingYears'].mean(),inplace=True)

# %%
data['TotalWorkingYears'] = data['TotalWorkingYears'].astype(int)
data['NumCompaniesWorked'] = data['NumCompaniesWorked'].astype(int)
data['EnvironmentSatisfaction'] = data['EnvironmentSatisfaction'].astype(int)
data['JobSatisfaction'] = data['JobSatisfaction'].astype(int)
data['WorkLifeBalance'] = data['WorkLifeBalance'].astype(int)

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
# 1. Stacked Area Chart
df_grouped = data.groupby(['YearsAtCompany', 'Attrition']).size().unstack()
df_grouped.plot(kind='area', stacked=True, figsize=(12, 6), alpha=0.7)
plt.title('Stacked Area Chart of Years at Company vs Attrition')
plt.ylabel('Count of Employees')
plt.xlabel('Years at Company')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='YearsAtCompany', y='MonthlyIncome', hue='Attrition', data=data)
plt.title('Monthly Income over Years at Company by Attrition')
plt.ylabel('Monthly Income')
plt.xlabel('Years at Company')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Age', y='MonthlyIncome', hue='Attrition', data=data)
plt.title('Scatterplot of Age vs Monthly Income by Attrition')
plt.ylabel('Monthly Income')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='MonthlyIncome', hue='Attrition', kde=True, element="step")
plt.title('Histogram and KDE of Monthly Income by Attrition')
plt.ylabel('Density')
plt.xlabel('Monthly Income')
plt.show()

# %%
attrition_counts = data['Attrition'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(attrition_counts, labels=attrition_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Donut Chart of Attrition')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x='Department', hue='Attrition', data=data)
plt.title('Countplot of Department by Attrition')
plt.ylabel('Count')
plt.xlabel('Department')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Age', hue='Attrition', kde=True, element="step")
plt.title('Histogram and KDE of Age by Attrition')
plt.ylabel('Density')
plt.xlabel('Age')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='MonthlyIncome', y='Age', hue='Attrition', data=data)
plt.title('Scatter Plot of Monthly Income vs Age by Attrition')
plt.xlabel('Monthly Income')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='JobRole', y='MonthlyIncome', hue='Attrition', data=data)
plt.title('Boxplot of Monthly Income by Job Role and Attrition')
plt.ylabel('Monthly Income')
plt.xlabel('Job Role')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='EducationField', y='MonthlyIncome', hue='Attrition', data=data, split=True)
plt.title('Violin Plot of Monthly Income by Education Field and Attrition')
plt.ylabel('Monthly Income')
plt.xlabel('Education Field')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='JobRole', y='MonthlyIncome', hue='Attrition', data=data)
plt.title('Bar Plot of Monthly Income by Job Role and Attrition')
plt.ylabel('Average Monthly Income')
plt.xlabel('Job Role')
plt.xticks(rotation=45)
plt.show()

# %%
sns.jointplot(x='Age', y='MonthlyIncome', data=data, hue='Attrition', kind='scatter')
plt.suptitle('Joint Plot of Age and Monthly Income by Attrition', y=1.02)
plt.show()

# %%
pivot_table = data.pivot_table(index='JobRole', columns='Department', values='Attrition', aggfunc='count').fillna(0)
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, annot=True, fmt='g', cmap='coolwarm')
plt.title('Heatmap of Attrition Counts by Job Role and Department')
plt.xlabel('Department')
plt.ylabel('Job Role')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.pointplot(x='Department', y='MonthlyIncome', hue='Attrition', data=data, dodge=True, markers=["o", "x"], linestyles=["-", "--"])
plt.title('Point Plot of Monthly Income by Department and Attrition')
plt.ylabel('Average Monthly Income')
plt.xlabel('Department')
plt.show()
# Out:
# c:\Users\MAAL SUBIKSHA\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1728: UserWarning: You passed a edgecolor/edgecolors ((0.8666666666666667, 0.5176470588235295, 0.3215686274509804)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='JobLevel', y='YearsAtCompany', hue='Attrition', data=data)
plt.title('Box Plot of Years at Company by Job Level and Attrition')
plt.ylabel('Years at Company')
plt.xlabel('Job Level')
plt.show()

# %% [markdown]
# CREATING A DASHBOARD OF THE ABOVE PLOTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import panel as pn

# Set up the plotting environment
sns.set(style="whitegrid")
pn.extension('plotly')

# 1. Stacked Area Chart
def stacked_area_chart():
    df_grouped = data.groupby(['YearsAtCompany', 'Attrition']).size().unstack()
    ax = df_grouped.plot(kind='area', stacked=True, figsize=(3, 4), alpha=0.7)
    ax.set_title('Stacked Area Chart of Years at Company vs Attrition')
    ax.set_ylabel('Count of Employees')
    ax.set_xlabel('Years at Company')
    return ax.get_figure()

# 2. Multiple Line Chart
def multiple_line_chart():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.lineplot(x='YearsAtCompany', y='MonthlyIncome', hue='Attrition', data=data, ax=ax)
    ax.set_title('Monthly Income over Years at Company by Attrition')
    ax.set_ylabel('Monthly Income')
    ax.set_xlabel('Years at Company')
    return fig

# 3. Scatterplot
def scatterplot():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.scatterplot(x='Age', y='MonthlyIncome', hue='Attrition', data=data, ax=ax)
    ax.set_title('Scatterplot of Age vs Monthly Income by Attrition')
    ax.set_ylabel('Monthly Income')
    ax.set_xlabel('Age')
    return fig

# 4. Distplot/Histplot
def distplot():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.histplot(data=data, x='MonthlyIncome', hue='Attrition', kde=True, element="step", ax=ax)
    ax.set_title('Histogram and KDE of Monthly Income by Attrition')
    ax.set_ylabel('Density')
    ax.set_xlabel('Monthly Income')
    return fig

# 5. Donut Chart
def donut_chart():
    attrition_counts = data['Attrition'].value_counts()
    fig, ax = plt.subplots(figsize=(3, 4))
    wedges, texts, autotexts = ax.pie(attrition_counts, labels=attrition_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
    for text in texts:
        text.set_color('grey')
    for autotext in autotexts:
        autotext.set_color('white')
    ax.set_title('Donut Chart of Attrition')
    return fig

# 7. Descriptive Statistics
def descriptive_statistics():
    return data.describe().to_html()

# 8. Countplot
def countplot():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.countplot(x='Department', hue='Attrition', data=data, ax=ax)
    ax.set_title('Countplot of Department by Attrition')
    ax.set_ylabel('Count')
    ax.set_xlabel('Department')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    return fig

# 9. Histogram
def histogram():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.histplot(data=data, x='Age', hue='Attrition', kde=True, element="step", ax=ax)
    ax.set_title('Histogram and KDE of Age by Attrition')
    ax.set_ylabel('Density')
    ax.set_xlabel('Age')
    return fig

# 10. Scatter Plot
def scatter_plot():
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.scatterplot(x='MonthlyIncome', y='Age', hue='Attrition', data=data, ax=ax)
    ax.set_title('Scatter Plot of Monthly Income vs Age by Attrition')
    ax.set_xlabel('Monthly Income')
    ax.set_ylabel('Age')
    return fig

# 11. Boxplot
def boxplot():
    fig, ax = plt.subplots(figsize=(5, 6))
    sns.boxplot(x='JobRole', y='MonthlyIncome', hue='Attrition', data=data, ax=ax)
    ax.set_title('Boxplot of Monthly Income by Job Role and Attrition')
    ax.set_ylabel('Monthly Income')
    ax.set_xlabel('Job Role')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    return fig

# 12. Violin Plot
def violin_plot():
    fig, ax = plt.subplots(figsize=(3,5))
    sns.violinplot(x='EducationField', y='MonthlyIncome', hue='Attrition', data=data, split=True, ax=ax)
    ax.set_title('Violin Plot of Monthly Income by Education Field and Attrition')
    ax.set_ylabel('Monthly Income')
    ax.set_xlabel('Education Field')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    return fig

# 13. Heatmap of Attrition Counts by Job Role and Department
def heatmap_attrition_counts():
    pivot_table = data.pivot_table(index='JobRole', columns='Department', values='Attrition', aggfunc='count').fillna(0)
    fig, ax = plt.subplots(figsize=(3, 4))
    sns.heatmap(pivot_table, annot=True, fmt='g', cmap='coolwarm', ax=ax)
    ax.set_title('Heatmap of Attrition Counts by Job Role and Department')
    ax.set_xlabel('Department')
    ax.set_ylabel('Job Role')
    return fig

# Create Panel layout
# Create CSS styles
css_styles = """
<style>
/* General Container Styling */
.grid-container {
    display: grid;
    grid-template-columns: repeat(3, 1fr);
    gap: 20px;
    padding: 20px;
    background-color: #f5f5f5;
    border-radius: 10px;
    box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
}

/* Grid Item Styling */
.grid-item {
    background-color: #ffffff;
    padding: 15px;
    border-radius: 8px;
    box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
    transition: transform 0.2s ease, box-shadow 0.2s ease;
    position: relative;
}

.grid-item:hover {
    transform: scale(1.03);
    box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.2);
}

.grid-item img {
    border: 1px solid #ddd;
    border-radius: 5px;
}

/* Header Styling */
.grid-header {
    grid-column: span 3;
    font-size: 28px;
    font-weight: bold;
    color: #333333;
    padding-bottom: 10px;
    border-bottom: 2px solid #cccccc;
    margin-bottom: 20px;
}

/* Responsive Design */
@media (max-width: 1200px) {
    .grid-container {
        grid-template-columns: repeat(2, 1fr);
    }
}

@media (max-width: 800px) {
    .grid-container {
        grid-template-columns: 1fr;
    }
}

/* Custom Styling for Markdown Headers */
.grid-header h1 {
    font-size: 36px;
}

.grid-header h2 {
    font-size: 30px;
}

/* Add Padding to HTML Descriptive Statistics */
.grid-item p {
    margin: 0;
    font-size: 14px;
    line-height: 1.6;
}
</style>
"""
# Create the Panel dashboard with grid layout and custom styles
dashboard = pn.Column(
    pn.pane.HTML(css_styles),
    pn.pane.HTML('<div class="grid-container">', sizing_mode='stretch_width'),
    pn.pane.Markdown("# Employee Attrition Analysis", css_classes=['grid-header']),
    
    pn.pane.Matplotlib(stacked_area_chart(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(multiple_line_chart(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(scatterplot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(distplot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(donut_chart(), tight=True, css_classes=['grid-item']),
    
    pn.pane.HTML(descriptive_statistics(), css_classes=['grid-item']),
    pn.pane.Matplotlib(countplot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(histogram(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(scatter_plot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(boxplot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(violin_plot(), tight=True, css_classes=['grid-item']),
    pn.pane.Matplotlib(heatmap_attrition_counts(), tight=True, css_classes=['grid-item']),
    
    pn.pane.HTML('</div>', sizing_mode='stretch_width')
)
# Serve the dashboard
dashboard.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6b17a18a-3e54-427f-ba1b-a4fbd04f9c98'>
#   <div id="e2a353b6-fdb2-4f24-9b9f-13c230b11731" data-root-id="6b17a18a-3e54-427f-ba1b-a4fbd04f9c98" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pn.serve(dashboard)
# Out:
# Launching server at http://localhost:58669

# %% [markdown]
# TRAINING AN ML MODEL TO PREDICT

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Convert categorical variables to numerical
label_encoders = {}
for column in data.select_dtypes(include=['object']).columns:
    if column != 'Attrition':  # Skip encoding the target variable for now
        label_encoders[column] = LabelEncoder()
        data[column] = label_encoders[column].fit_transform(data[column])

# Encode target variable 'Attrition'
data['Attrition'] = data['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# Split data into features and target
X = data.drop(columns=['Attrition', 'EmployeeID'])  # Exclude 'EmployeeID' and target variable
y = data['Attrition']

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame for better readability
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)

# Display the shapes of the resulting datasets
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (3528, 27)
# X_test shape: (882, 27)
# y_train shape: (3528,)
# y_test shape: (882,)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))

# Feature importance
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title('Feature Importance')
plt.show()
# Out:
# Accuracy: 0.9920634920634921
# Confusion Matrix:
#  [[741   0]
#  [  7 134]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       741
#            1       1.00      0.95      0.97       141
#
#     accuracy                           0.99       882
#    macro avg       1.00      0.98      0.98       882
# weighted avg       0.99      0.99      0.99       882

# %% [markdown]
# MAIN KPI'S OF THE ANALYSIS

# %%
# Calculate Average Tenure
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='YearsAtCompany', hue='Attrition', multiple='stack', bins=20)
plt.title('Distribution of Years at Company by Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Count')
plt.show()

# %%
# Environment Satisfaction
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='EnvironmentSatisfaction')
plt.title('Environment Satisfaction by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Environment Satisfaction')
plt.show()

# Job Satisfaction
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='JobSatisfaction')
plt.title('Job Satisfaction by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Job Satisfaction')
plt.show()

# Work-Life Balance
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='WorkLifeBalance')
plt.title('Work-Life Balance by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Work-Life Balance')
plt.show()

# %%
# Monthly Income Distribution
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %%
# Performance Rating Distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='PerformanceRating', hue='Attrition')
plt.title('Performance Rating by Attrition')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.show()

# %%
# Years Since Last Promotion
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='YearsSinceLastPromotion')
plt.title('Years Since Last Promotion by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Years Since Last Promotion')
plt.show()

# %%
# Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='Age', hue='Attrition', multiple='stack', bins=20)
plt.title('Age Distribution by Attrition')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# Gender Distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Gender', hue='Attrition')
plt.title('Gender Distribution by Attrition')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Training Times Last Year
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='TrainingTimesLastYear')
plt.title('Training Times Last Year by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Training Times Last Year')
plt.show()

# %%
# Total Working Years
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='TotalWorkingYears')
plt.title('Total Working Years by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Total Working Years')
plt.show()
